# %%
import mercabilbao
#Descargar módulo en https://github.com/abediaga/mercados_mayoristas/raw/master/mercabilbao.py

# %%
anos = ["2020","2019"]
mercado = "Hortalizas"
informacion = "Productos"
productos = ["Coliflor", "Brocoli"]
indicador = "Preciomás frecuente"

dff_producto = mercabilbao.get_dataframe_mercabilbao(anos,mercado,informacion,productos,indicador)
display(dff_producto)
mercabilbao.plot_dataframe_mercabilbao(dff_producto)
# Out:
#           2019-01-04  2019-01-11  2019-01-18  2019-01-25  2019-02-01  \
# Brocoli          0.8        0.80        0.98        0.90        0.83
# Coliflor         0.5        0.67        0.82        0.75        0.56
#
#           2019-02-08  2019-02-15  2019-02-22  2019-03-01  2019-03-08  ...  \
# Brocoli         0.82        0.90         0.8        0.80        0.84  ...
# Coliflor        0.50        0.51         0.5        0.52        0.48  ...
#
#           2020-01-31  2020-02-07  2020-02-14  2020-02-21  2020-02-28  \
# Brocoli         1.11        1.00         1.0        1.00        1.00
# Coliflor        0.88        0.56         0.5        0.49        0.48
#
#           2020-03-06  2020-03-13  2020-03-20  2020-03-27  2020-04-03
# Brocoli         1.13         1.1         1.4        1.40        2.67
# Coliflor        0.56         0.7         0.8        0.78        1.04
#
# [2 rows x 66 columns]
